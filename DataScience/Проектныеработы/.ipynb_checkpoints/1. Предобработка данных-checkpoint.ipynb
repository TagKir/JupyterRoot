# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\tagir\Downloads\data.csv")

# %%
# 2
df.loc[df['days_employed'] < 0, 'days_employed'] *= -1 
df['days_employed'] = df['days_employed'].fillna(value = df['days_employed'].median())
df.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1    8437.673028         42               высшее             0
# 1          1    4024.803754         36              среднее             1
# 2          0    5623.422610         33              Среднее             1
# 3          3    4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0     926.185831         27               высшее             0
# 6          0    2879.202052         43               высшее             0
# 7          0     152.779569         50              СРЕДНЕЕ             1
# 8          2    6929.865299         35               ВЫСШЕЕ             0
# 9          0    2188.756445         41              среднее             1
# 10         2    4171.483647         36               высшее             0
# 11         0     792.701887         40              среднее             1
# ...

# %%
# 3
df = df.fillna(0)
df['total_income'] = df['total_income'].astype('int')

# %%
# 4

df['education'] = df['education'].str.capitalize()
"""Причины появления дубликатов:
Сбой, человеческий фактор, плохое составление таблицы"""
# Out:
# 'Причины появления дубликатов:\nСбой, человеческий фактор, плохое составление таблицы'

# %%
# 5 

df1 = pd.DataFrame(data = df, columns = ['education_id', 'education'])
df2 = pd.DataFrame(data = df, columns = ['family_status_id', 'family_status'])
df = df.drop(['education', 'family_status'], axis=1)

# %%
# 6 
df
df['total_income_category'] = ''
n = 0
while n < 21525:
    if (df.loc[n, 'total_income'] < 30000).any():
        df.loc[n, 'total_income_category'] = 'E'
    elif ((df.loc[n, 'total_income'] < 50000) & (df.loc[n, 'total_income'] > 30000)).any():
        df.loc[n, 'total_income_category'] = 'D'
    elif ((df.loc[n, 'total_income'] < 200000) & (df.loc[n, 'total_income'] > 50000)).all(): 
        df.loc[n, 'total_income_category'] = 'C'
    elif ((df.loc[n, 'total_income'] < 1000000) & (df.loc[n, 'total_income'] > 200000)).all():   
        df.loc[n, 'total_income_category'] = 'B'
    elif (df.loc[n, 'total_income'] > 1000000).all():      
        df.loc[n, 'total_income_category'] = 'A'
    n += 1
# 00:47. У меня сегодня игра, а я сделал это.УРРАААА

# %%
# 7
def purp_cat(dff):
    if 'автомобил' in dff:
        return 'операции с автомобилем'
    elif 'жиль' in dff:
        return 'операции с недвижимостью'
    elif 'недвиж' in dff:
        return 'операции с недвижимостью'
    elif 'свадьб' in dff: 
        return 'проведение свадьбы'
    elif 'образов' in dff:   
        return 'получение образования'
        
   
df_series = df['purpose'].squeeze()
df['purp_cat'] = df_series.apply(purp_cat)

df
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0  340266.072047         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21520         1    4529.316663         43             1                 1
# 21521         0  343937.404131         67             1                 0
# 21522         1    2113.346888         38             1                 1
# 21523         3    3112.481705         38             1                 0
# 21524         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                       purpose  \
# ...
