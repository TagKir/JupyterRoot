# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
import numpy as np


# 1:
df1 = pd.read_csv(r"C:\Users\tagir\Downloads\mkrf_shows.csv")
df2 = pd.read_csv(r"C:\Users\tagir\Downloads\mkrf_movies.csv")

df = df1.join(df2, lsuffix='_caller', rsuffix='_other')
df = df.replace({np.nan:None})
df['ratings'] = df['ratings'].str.rstrip("%").astype(float)
#df.head()

# %%
# 2.1 - 2.5
df.loc[1797, 'puNumber_other'] = '000000000'
df['puNumber_other'] = df['puNumber_other'].astype(int)

df['show_start_date'] = pd.to_datetime(df['show_start_date'], format='%Y-%m-%dT%H:%M:%S.%f', utc=False)
df['show_start_date'] = pd.to_datetime(df.show_start_date).dt.tz_localize(None)
df['film_studio'] = df['film_studio'].fillna('Неизвестно')
df['director'] = df['director'].fillna('Неизвестно')
df['producer'] = df['producer'].fillna('Неизвестно')
df['age_restriction'] = df['age_restriction'].fillna('Неизвестно')
df['refundable_support'] = df['refundable_support'].fillna(0)
df['nonrefundable_support'] = df['nonrefundable_support'].fillna(0)
df['budget'] = df['budget'].fillna('Собственный')
df['financing_source'] = df['financing_source'].fillna('Неизвестно|Сами')
df['ratings'] = df['ratings'].fillna(0)
df.loc[df['ratings'] > 10, 'ratings'] /= 10
df.loc[df['ratings']==0, 'ratings'] = 'Неизвестно'
df['genres'] = df['genres'].fillna('Неизвестно')
df.drop_duplicates(subset=['title', 'show_start_date'], inplace=True, ignore_index=True)
 


#df['ratings'].value_counts()
# df.query('ratings != "None"')

# %%
# 2.6(1,2,3)
# 1
df['year_of_show_date', ] = df['show_start_date'].dt.year
# 2
# df['main_director'] = df['director']
# df['main_genre'] = 
# Мне нужно понять как получить первое значение в ячейках

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3153 entries, 0 to 3152
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   puNumber_caller        3153 non-null   int64
#  1   box_office             3153 non-null   object
#  2   title                  3153 non-null   object
#  3   puNumber_other         3153 non-null   int32
#  4   show_start_date        3153 non-null   datetime64[ns]
#  5   type                   3153 non-null   object
#  6   film_studio            3153 non-null   object
#  7   production_country     3153 non-null   object
#  8   director               3153 non-null   object
#  9   producer               3153 non-null   object
#  10  age_restriction        3153 non-null   object
#  11  refundable_support     3153 non-null   float64
#  12  nonrefundable_support  3153 non-null   float64
#  13  budget                 3153 non-null   object
# ...

# %%
df.head(20)
# Out:
#     puNumber_caller    box_office  \
# 0         111000113        2450.0
# 1         111000115       61040.0
# 2         111000116   153030013.4
# 3         111000117    12260956.0
# 4         111000118  163684057.79
# 5         111000119    4293649.51
# 6         111000212         200.0
# 7         111000216      355567.0
# 8         111000313         710.0
# 9         111000314     1607970.0
# 10        111000315       36550.0
# 11        111000318   56357980.56
# 12        111000319  194845829.65
# 13        111000411       11740.0
# 14        111000412        1920.0
# 15        111000413        7104.0
# 16        111000415   446163511.0
# 17        111000416   81430626.82
# 18        111000417   123970133.0
# 19        111000419   53449711.94
#
#                                                 title  puNumber_other  \
# 0                                    Открытый простор       221048915
# 1                                Особо важное задание       111013716
# ...
